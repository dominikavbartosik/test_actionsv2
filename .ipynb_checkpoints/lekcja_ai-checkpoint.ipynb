# %%
import os
import string
from collections import defaultdict
import re

# %%
def letter_freq(text: str):
    text = [x for x in text.lower() if x in string.ascii_lowercase]
    total_len = len(text)

    freq = defaultdict(int)
    for c in string.ascii_lowercase:
        freq[c] = 0
        
    for c in text:
        freq[c] += 1
    return {c:v/total_len for c,v in freq.items()}

# %%
letter_freq("aaab")
# Out:
# {'a': 0.75,
#  'b': 0.25,
#  'c': 0.0,
#  'd': 0.0,
#  'e': 0.0,
#  'f': 0.0,
#  'g': 0.0,
#  'h': 0.0,
#  'i': 0.0,
#  'j': 0.0,
#  'k': 0.0,
#  'l': 0.0,
#  'm': 0.0,
#  'n': 0.0,
#  'o': 0.0,
#  'p': 0.0,
#  'q': 0.0,
#  'r': 0.0,
#  's': 0.0,
#  't': 0.0,
#  'u': 0.0,
#  'v': 0.0,
#  'w': 0.0,
#  'x': 0.0,
#  'y': 0.0,
#  'z': 0.0}

# %%
def load_data(path: str):
    files = os.listdir(path)
    results = []
    for file in files:
        with open(os.path.join(path, file), "r", encoding="utf-8") as f:
            file_data = letter_freq(f.read())
            language = re.match(r'[A-Za-z0-9]+_([a-z]{2})\.txt', file)
            results.append([file_data, language.group(1)])
    return results

# %%
train_data = load_data("./dataset/train")
train_data
# Out:
# [[{'a': 0.08530522966792603,
#    'b': 0.02704314973155697,
#    'c': 0.03619009743487771,
#    'd': 0.03559355736726984,
#    'e': 0.11712069994034599,
#    'f': 0.020680055677072977,
#    'g': 0.020083515609465103,
#    'h': 0.05786438655796381,
#    'i': 0.06323324716643468,
#    'j': 0.006164247365281368,
#    'k': 0.006959634122091867,
#    'l': 0.03976933784052496,
#    'm': 0.0208789023662756,
#    'n': 0.0618413203420163,
#    'o': 0.06402863392324518,
#    'p': 0.014316961622588983,
#    'q': 0.00019884668920262477,
#    'r': 0.07019288128852655,
#    's': 0.07178365480214755,
#    't': 0.10379797176377013,
#    'u': 0.03996818452972758,
#    'v': 0.007755020878902366,
#    'w': 0.013919268244183734,
#    'x': 0.000994233446013124,
#    'y': 0.014316961622588983,
#    'z': 0.0},
#   'en'],
#  [{'a': 0.11355034065102196,
#    'b': 0.00984102952308857,
#    'c': 0.045041635124905374,
#    'd': 0.03368660105980318,
#    'e': 0.13626040878122633,
#    'f': 0.010219530658591975,
#    'g': 0.019303557910673733,
#    'h': 0.006813020439061317,
#    'i': 0.10068130204390613,
#    'j': 0.0,
#    'k': 0.0,
#    'l': 0.06699470098410296,
#    'm': 0.025738077214231644,
#    'n': 0.06510219530658592,
#    'o': 0.08516275548826646,
#    'p': 0.0291445874337623,
#    'q': 0.002271006813020439,
#    'r': 0.06926570779712339,
#    's': 0.05866767600302801,
#    't': 0.08364875094625283,
#    'u': 0.020817562452687358,
#    'v': 0.014004542013626041,
#    'w': 0.0,
#    'x': 0.0,
#    'y': 0.0,
#    'z': 0.003785011355034065},
#   'it'],
#  [{'a': 0.07561532605937579,
#    'b': 0.022075615326059377,
#    'c': 0.02537427048972342,
#    'd': 0.04592742958639939,
#    'e': 0.12814006597310326,
#    'f': 0.024359299670134484,
#    'g': 0.017254503933011926,
#    'h': 0.05430093884800812,
#    'i': 0.06521187515858919,
#    'j': 0.0053285968028419185,
#    'k': 0.01750824663790916,
#    'l': 0.05100228368434408,
#    'm': 0.019030702867292564,
#    'n': 0.07764526769855366,
#    'o': 0.07003298655163664,
#    'p': 0.01623953311342299,
#    'q': 0.001268713524486171,
#    'r': 0.05962953565085004,
#    's': 0.07485409794468409,
#    't': 0.07663029687896473,
#    'u': 0.02461304237503172,
#    'v': 0.0096422227860949,
#    'w': 0.021568129916264906,
#    'x': 0.0038061405734585133,
#    'y': 0.012433392539964476,
#    'z': 0.0005074854097944684},
#   'en'],
#  [{'a': 0.10428619642254472,
#    'b': 0.006243671954100574,
#    'c': 0.03442456969287884,
#    'd': 0.04454944313196085,
#    'e': 0.1130610867364158,
#    'f': 0.00809989875126561,
#    'g': 0.02564967937900776,
#    'h': 0.005568680391495107,
#    'i': 0.1400607492406345,
#    'j': 0.00016874789065136686,
#    'k': 0.00641241984475194,
#    'l': 0.06648666891663854,
#    'm': 0.02632467094161323,
#    'n': 0.07154910563617954,
#    'o': 0.08201147485656429,
#    'p': 0.03408707391157611,
#    'q': 0.003712453594330071,
#    'r': 0.05028687141410732,
#    's': 0.042861964225447184,
#    't': 0.06935538305771177,
#    'u': 0.033580830239622,
#    'v': 0.015187310158623017,
#    'w': 0.006749915626054675,
#    'x': 0.00016874789065136686,
#    'y': 0.0003374957813027337,
#    'z': 0.008774890313871077},
#   'it'],
#  [{'a': 0.08354529446292311,
#    'b': 0.013891606339268244,
#    'c': 0.028761494815104677,
#    'd': 0.05400117393856388,
#    'e': 0.12208961064370964,
#    'f': 0.01780473488554099,
#    'g': 0.026217961260027393,
#    'h': 0.05654470749364117,
#    'i': 0.07043631383290941,
#    'j': 0.002347877127763647,
#    'k': 0.012522011348072784,
#    'l': 0.03854431618078654,
#    'm': 0.030131089806300138,
#    'n': 0.07747994521620036,
#    'o': 0.06339268244961847,
#    'p': 0.019956955585991,
#    'q': 0.0003913128546272745,
#    'r': 0.05224026609274115,
#    's': 0.0751320680884367,
#    't': 0.0813930737624731,
#    'u': 0.02778321267853649,
#    'v': 0.010369790647622775,
#    'w': 0.02073958129524555,
#    'x': 0.0003913128546272745,
#    'y': 0.013695949911954608,
#    'z': 0.00019565642731363725},
#   'en'],
#  [{'a': 0.11144859813084113,
#    'b': 0.00911214953271028,
#    'c': 0.04007009345794393,
#    'd': 0.041121495327102804,
#    'e': 0.11460280373831776,
#    'f': 0.008995327102803739,
#    'g': 0.016588785046728973,
#    'h': 0.013434579439252336,
#    'i': 0.12149532710280374,
#    'j': 0.0,
#    'k': 0.00023364485981308412,
#    'l': 0.07464953271028038,
#    'm': 0.026518691588785046,
#    'n': 0.07242990654205607,
#    'o': 0.08352803738317757,
#    'p': 0.02453271028037383,
#    'q': 0.001869158878504673,
#    'r': 0.0669392523364486,
#    's': 0.0514018691588785,
#    't': 0.06670560747663551,
#    'u': 0.024182242990654204,
#    'v': 0.015186915887850467,
#    'w': 0.0014018691588785046,
#    'x': 0.00011682242990654206,
#    'y': 0.0,
#    'z': 0.013434579439252336},
#   'it']]

# %%
def encode_labels(labels):
    unique_values = list(set(labels))
    unique_values.sort()
    return {k:i+1 for i, k in enumerate(unique_values)}

# %%
encoded_labels = encode_labels([label for freq, label in train_data])
encoded_labels
# Out:
# {'en': 1, 'it': 2}

# %%
encoded_labels["it"]
# Out:
# 2

# %%
train_data = [[freq, encoded_labels[label]] for freq, label in train_data]
train_data
# Out:
# [[{'a': 0.08530522966792603,
#    'b': 0.02704314973155697,
#    'c': 0.03619009743487771,
#    'd': 0.03559355736726984,
#    'e': 0.11712069994034599,
#    'f': 0.020680055677072977,
#    'g': 0.020083515609465103,
#    'h': 0.05786438655796381,
#    'i': 0.06323324716643468,
#    'j': 0.006164247365281368,
#    'k': 0.006959634122091867,
#    'l': 0.03976933784052496,
#    'm': 0.0208789023662756,
#    'n': 0.0618413203420163,
#    'o': 0.06402863392324518,
#    'p': 0.014316961622588983,
#    'q': 0.00019884668920262477,
#    'r': 0.07019288128852655,
#    's': 0.07178365480214755,
#    't': 0.10379797176377013,
#    'u': 0.03996818452972758,
#    'v': 0.007755020878902366,
#    'w': 0.013919268244183734,
#    'x': 0.000994233446013124,
#    'y': 0.014316961622588983,
#    'z': 0.0},
#   1],
#  [{'a': 0.11355034065102196,
#    'b': 0.00984102952308857,
#    'c': 0.045041635124905374,
#    'd': 0.03368660105980318,
#    'e': 0.13626040878122633,
#    'f': 0.010219530658591975,
#    'g': 0.019303557910673733,
#    'h': 0.006813020439061317,
#    'i': 0.10068130204390613,
#    'j': 0.0,
#    'k': 0.0,
#    'l': 0.06699470098410296,
#    'm': 0.025738077214231644,
#    'n': 0.06510219530658592,
#    'o': 0.08516275548826646,
#    'p': 0.0291445874337623,
#    'q': 0.002271006813020439,
#    'r': 0.06926570779712339,
#    's': 0.05866767600302801,
#    't': 0.08364875094625283,
#    'u': 0.020817562452687358,
#    'v': 0.014004542013626041,
#    'w': 0.0,
#    'x': 0.0,
#    'y': 0.0,
#    'z': 0.003785011355034065},
#   2],
#  [{'a': 0.07561532605937579,
#    'b': 0.022075615326059377,
#    'c': 0.02537427048972342,
#    'd': 0.04592742958639939,
#    'e': 0.12814006597310326,
#    'f': 0.024359299670134484,
#    'g': 0.017254503933011926,
#    'h': 0.05430093884800812,
#    'i': 0.06521187515858919,
#    'j': 0.0053285968028419185,
#    'k': 0.01750824663790916,
#    'l': 0.05100228368434408,
#    'm': 0.019030702867292564,
#    'n': 0.07764526769855366,
#    'o': 0.07003298655163664,
#    'p': 0.01623953311342299,
#    'q': 0.001268713524486171,
#    'r': 0.05962953565085004,
#    's': 0.07485409794468409,
#    't': 0.07663029687896473,
#    'u': 0.02461304237503172,
#    'v': 0.0096422227860949,
#    'w': 0.021568129916264906,
#    'x': 0.0038061405734585133,
#    'y': 0.012433392539964476,
#    'z': 0.0005074854097944684},
#   1],
#  [{'a': 0.10428619642254472,
#    'b': 0.006243671954100574,
#    'c': 0.03442456969287884,
#    'd': 0.04454944313196085,
#    'e': 0.1130610867364158,
#    'f': 0.00809989875126561,
#    'g': 0.02564967937900776,
#    'h': 0.005568680391495107,
#    'i': 0.1400607492406345,
#    'j': 0.00016874789065136686,
#    'k': 0.00641241984475194,
#    'l': 0.06648666891663854,
#    'm': 0.02632467094161323,
#    'n': 0.07154910563617954,
#    'o': 0.08201147485656429,
#    'p': 0.03408707391157611,
#    'q': 0.003712453594330071,
#    'r': 0.05028687141410732,
#    's': 0.042861964225447184,
#    't': 0.06935538305771177,
#    'u': 0.033580830239622,
#    'v': 0.015187310158623017,
#    'w': 0.006749915626054675,
#    'x': 0.00016874789065136686,
#    'y': 0.0003374957813027337,
#    'z': 0.008774890313871077},
#   2],
#  [{'a': 0.08354529446292311,
#    'b': 0.013891606339268244,
#    'c': 0.028761494815104677,
#    'd': 0.05400117393856388,
#    'e': 0.12208961064370964,
#    'f': 0.01780473488554099,
#    'g': 0.026217961260027393,
#    'h': 0.05654470749364117,
#    'i': 0.07043631383290941,
#    'j': 0.002347877127763647,
#    'k': 0.012522011348072784,
#    'l': 0.03854431618078654,
#    'm': 0.030131089806300138,
#    'n': 0.07747994521620036,
#    'o': 0.06339268244961847,
#    'p': 0.019956955585991,
#    'q': 0.0003913128546272745,
#    'r': 0.05224026609274115,
#    's': 0.0751320680884367,
#    't': 0.0813930737624731,
#    'u': 0.02778321267853649,
#    'v': 0.010369790647622775,
#    'w': 0.02073958129524555,
#    'x': 0.0003913128546272745,
#    'y': 0.013695949911954608,
#    'z': 0.00019565642731363725},
#   1],
#  [{'a': 0.11144859813084113,
#    'b': 0.00911214953271028,
#    'c': 0.04007009345794393,
#    'd': 0.041121495327102804,
#    'e': 0.11460280373831776,
#    'f': 0.008995327102803739,
#    'g': 0.016588785046728973,
#    'h': 0.013434579439252336,
#    'i': 0.12149532710280374,
#    'j': 0.0,
#    'k': 0.00023364485981308412,
#    'l': 0.07464953271028038,
#    'm': 0.026518691588785046,
#    'n': 0.07242990654205607,
#    'o': 0.08352803738317757,
#    'p': 0.02453271028037383,
#    'q': 0.001869158878504673,
#    'r': 0.0669392523364486,
#    's': 0.0514018691588785,
#    't': 0.06670560747663551,
#    'u': 0.024182242990654204,
#    'v': 0.015186915887850467,
#    'w': 0.0014018691588785046,
#    'x': 0.00011682242990654206,
#    'y': 0.0,
#    'z': 0.013434579439252336},
#   2]]

# %%
X_train = [list(freq.values()) for freq, label in train_data]
X_train
# Out:
# [[0.08530522966792603,
#   0.02704314973155697,
#   0.03619009743487771,
#   0.03559355736726984,
#   0.11712069994034599,
#   0.020680055677072977,
#   0.020083515609465103,
#   0.05786438655796381,
#   0.06323324716643468,
#   0.006164247365281368,
#   0.006959634122091867,
#   0.03976933784052496,
#   0.0208789023662756,
#   0.0618413203420163,
#   0.06402863392324518,
#   0.014316961622588983,
#   0.00019884668920262477,
#   0.07019288128852655,
#   0.07178365480214755,
#   0.10379797176377013,
#   0.03996818452972758,
#   0.007755020878902366,
#   0.013919268244183734,
#   0.000994233446013124,
#   0.014316961622588983,
#   0.0],
#  [0.11355034065102196,
#   0.00984102952308857,
#   0.045041635124905374,
#   0.03368660105980318,
#   0.13626040878122633,
#   0.010219530658591975,
#   0.019303557910673733,
#   0.006813020439061317,
#   0.10068130204390613,
#   0.0,
#   0.0,
#   0.06699470098410296,
#   0.025738077214231644,
#   0.06510219530658592,
#   0.08516275548826646,
#   0.0291445874337623,
#   0.002271006813020439,
#   0.06926570779712339,
#   0.05866767600302801,
#   0.08364875094625283,
#   0.020817562452687358,
#   0.014004542013626041,
#   0.0,
#   0.0,
#   0.0,
#   0.003785011355034065],
#  [0.07561532605937579,
#   0.022075615326059377,
#   0.02537427048972342,
#   0.04592742958639939,
#   0.12814006597310326,
#   0.024359299670134484,
#   0.017254503933011926,
#   0.05430093884800812,
#   0.06521187515858919,
#   0.0053285968028419185,
#   0.01750824663790916,
#   0.05100228368434408,
#   0.019030702867292564,
#   0.07764526769855366,
#   0.07003298655163664,
#   0.01623953311342299,
#   0.001268713524486171,
#   0.05962953565085004,
#   0.07485409794468409,
#   0.07663029687896473,
#   0.02461304237503172,
#   0.0096422227860949,
#   0.021568129916264906,
#   0.0038061405734585133,
#   0.012433392539964476,
#   0.0005074854097944684],
#  [0.10428619642254472,
#   0.006243671954100574,
#   0.03442456969287884,
#   0.04454944313196085,
#   0.1130610867364158,
#   0.00809989875126561,
#   0.02564967937900776,
#   0.005568680391495107,
#   0.1400607492406345,
#   0.00016874789065136686,
#   0.00641241984475194,
#   0.06648666891663854,
#   0.02632467094161323,
#   0.07154910563617954,
#   0.08201147485656429,
#   0.03408707391157611,
#   0.003712453594330071,
#   0.05028687141410732,
#   0.042861964225447184,
#   0.06935538305771177,
#   0.033580830239622,
#   0.015187310158623017,
#   0.006749915626054675,
#   0.00016874789065136686,
#   0.0003374957813027337,
#   0.008774890313871077],
#  [0.08354529446292311,
#   0.013891606339268244,
#   0.028761494815104677,
#   0.05400117393856388,
#   0.12208961064370964,
#   0.01780473488554099,
#   0.026217961260027393,
#   0.05654470749364117,
#   0.07043631383290941,
#   0.002347877127763647,
#   0.012522011348072784,
#   0.03854431618078654,
#   0.030131089806300138,
#   0.07747994521620036,
#   0.06339268244961847,
#   0.019956955585991,
#   0.0003913128546272745,
#   0.05224026609274115,
#   0.0751320680884367,
#   0.0813930737624731,
#   0.02778321267853649,
#   0.010369790647622775,
#   0.02073958129524555,
#   0.0003913128546272745,
#   0.013695949911954608,
#   0.00019565642731363725],
#  [0.11144859813084113,
#   0.00911214953271028,
#   0.04007009345794393,
#   0.041121495327102804,
#   0.11460280373831776,
#   0.008995327102803739,
#   0.016588785046728973,
#   0.013434579439252336,
#   0.12149532710280374,
#   0.0,
#   0.00023364485981308412,
#   0.07464953271028038,
#   0.026518691588785046,
#   0.07242990654205607,
#   0.08352803738317757,
#   0.02453271028037383,
#   0.001869158878504673,
#   0.0669392523364486,
#   0.0514018691588785,
#   0.06670560747663551,
#   0.024182242990654204,
#   0.015186915887850467,
#   0.0014018691588785046,
#   0.00011682242990654206,
#   0.0,
#   0.013434579439252336]]

# %%
y_train = [label for freq, label in train_data]
y_train
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
def train(data, labels, epochs, learning_rate):
    num_features = len(data[0])
    weights = [0] * num_features
    bias = 0

    def activiation(x):
        return 1 if x >= 0 else -1

    for epoch in range(epochs):
        for x, y in zip(data, labels):
            output = sum(w * f for w, f in zip(weights, x)) + bias
            prediction = activation(output)

# %%
train(X_train, y_train, epochs=10, learning_rate=0.1)
